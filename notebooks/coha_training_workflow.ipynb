# %% [markdown]
# # **`word2vec` Training Workflow (Davies Corpora)**
# In this workflow, we first train `word2vec` models across years using a range of hyperparameters (e.g., vector dimensions and training epochs). The purpose is twofold: (1) to determine whether models from earlier years are reasonably stable, and (2) choose a set of hyperparameters that yield good results across all years. Models are evaluated using "intrinsic" tests of similarity and analogy performance, which we visualize using plots and analyze using linear regression.
#
# Once we've chosen our hyperparameters, we use them to train models for every year from 1900 through 2019.

# %% [markdown]
# ## **Setup**
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

from train.word2vec import (
    train_models,
    transfer_models
)
import shutil
from pathlib import Path
from train.word2vec.evaluate import evaluate_models
from train.word2vec.visualize import plot_evaluation_results
from train.word2vec.regression_analysis import run_regression_analysis, plot_regression_results
from train.word2vec.normalize_and_align_models import normalize_and_align_vectors

# %% [markdown]
# ### Configure
# Here we set basic parameters: the corpus name, database path, and any corpus-specific settings.

# %%
corpus_name = 'COCA'
genre_focus = None
db_path_stub = f'/scratch/edk202/NLP_corpora/{corpus_name}/'

# %% [markdown]
# ## **Test Model Hyperparameters**
# ### Train Models
# We test models across available years, cycling through a range of reasonable hyperparameters. For Davies corpora like COHA, we constrain our grid search as follows:
# 1. We stick to the Skip-Gram (`skip-gram`) approach. Skip-gram generally performs well for semantic similarity tasks.
# 2. We test vector dimensions (`vector_size`) from 100 to 300. Our vocabulary size supports meaningful feature extraction in this range.
# 3. We test training epochs (`epochs`) from 10 to 30. More than 30 epochs risks overfitting.
# 4. We set the minimum word count (`min_count`) to 1, meaning that no words will be excluded from training. Our whitelist filtering ensures that all vocabulary words appear with sufficient frequency.
# 5. Weighting (`weight_by`) is set to none. `word2vec` already implements frequency-based downweighting.
# 6. We use a context window (`window`) appropriate for the full sentence context available in Davies corpora.

# %%
train_models(
    corpus_path=db_path_stub,
    genre_focus=genre_focus,
    years=(1950, 2019),
    year_step=1,
    dir_suffix='test',
    weight_by=('none',),
    vector_size=(100, 200, 300),
    window=(15,),
    min_count=(1,),
    approach=('skip-gram',),
    epochs=(10, 20, 30),
    max_parallel_models=120,
    workers_per_model=16,
    mode="restart",
    unk_mode="strip",
    use_corpus_file=True,
    cache_corpus=True,
    temp_dir=Path('/scratch/edk202/lexichron/temp/')
);
# Out:
# Temporary corpus directory: /scratch/edk202/lexichron/temp
#
# WORD2VEC MODEL TRAINING
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-01-16 19:08:02
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Database:             /scratch/edk202/NLP_corpora/COCA/COCA_filtered
# Model directory:      /scratch/edk202/NLP_models/COCA/COCA/models_test
# Log directory:        /scratch/edk202/NLP_models/COCA/COCA/logs_test/training
# Parallel models:      120
#
# Training Parameters
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Years:                1950–2019 (step=5, 14 years)
# Weighting:            ('none',)
# Vector size:          (100, 200, 300)
# Context window:       (15,)
# Minimum word count:   (1,)
# Approach:             ('skip-gram',)
# Training epochs:      (10, 20, 30)
#
# Data Options
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# UNK mode:             strip
# Corpus mode:          Shared corpus file (one per year/weight)
# Workers per model:    16
#
#
# Execution
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Total models in grid: 126
# Models to train:      126
# Parameter combos:     9
# Years:                14
#
# Creating corpus files in parallel...
#   Created corpus file for year 1970, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1970_wbnone_r1_otjz6.txt
#   Created corpus file for year 1960, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1960_wbnone_yiwn_zjl.txt
#   Created corpus file for year 1955, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1955_wbnone_lexi91ce.txt
#   Created corpus file for year 1985, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1985_wbnone_4hvm2kw0.txt
#   Created corpus file for year 1950, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1950_wbnone_nncm5yxs.txt
#   Created corpus file for year 1975, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1975_wbnone_zy8jo2dk.txt
#   Created corpus file for year 1980, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1980_wbnone_fg2tpvwv.txt
#   Created corpus file for year 1965, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1965_wbnone_2di11nbb.txt
#   Created corpus file for year 2010, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y2010_wbnone_2i83kld0.txt
#   Created corpus file for year 2015, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y2015_wbnone_lsumug3m.txt
#   Created corpus file for year 1995, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1995_wbnone_f7ww_43l.txt
#   Created corpus file for year 2005, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y2005_wbnone_8esg8ux2.txt
#   Created corpus file for year 2000, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y2000_wbnone_ow_m8n32.txt
#   Created corpus file for year 1990, weight_by=none: /scratch/edk202/lexichron/temp/w2v_corpus_y1990_wbnone_wn_aonau.txt
# Training Models:  29%|██▊       | 36/126 [00:01<00:02, 35.36 models/s]
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
# Training Models:  30%|███       | 38/126 [00:01<00:02, 35.36 models/s]
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
# Training Models:  37%|███▋      | 46/126 [00:01<00:02, 34.89 models/s]
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
# Training Models:  40%|███▉      | 50/126 [00:01<00:02, 34.89 models/s]
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
# Training Models:  40%|████      | 51/126 [00:02<00:02, 34.89 models/s]
# Task failed with error: you must first build vocabulary before training the model
# Training Models:  54%|█████▍    | 68/126 [00:02<00:02, 21.01 models/s]
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
# Training Models:  56%|█████▌    | 70/126 [00:02<00:02, 25.56 models/s]
# Task failed with error: you must first build vocabulary before training the model
#
# Task failed with error: you must first build vocabulary before training the model
# Training Models:  56%|█████▋    | 71/126 [00:03<00:02, 25.56 models/s]
# Task failed with error: you must first build vocabulary before training the model

# %% [markdown]
# ### Evaluate Models
#
# We can evaluate the models we've trained using two "intrinsic" tests: (1) a _similarity test_ assessing how well each model predicts human-rated synonymy judgments, and (2) an _analogy test_ assessing how well each model can answer SAT-style analogy questions. Test results are saved to a CSV file.
#
# Similarity performance is the metric of choice for models intended to track semantic relatedness over time. However, we run both tests here to demonstrate the evaluation code and show that different hyperparameters lend themselves to different performance metrics.

# %%
evaluate_models(
    corpus_path=db_path_stub,
    genre_focus=genre_focus,
    dir_suffix='test',
    save_mode='overwrite',
    run_similarity=True,
    run_analogy=True,
    workers=128
);
# Out:
# WORD2VEC MODEL EVALUATION
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-01-15 23:18:55
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Model directory:      /scratch/edk202/NLP_models/COHA/COHA/models_test
# Evaluation file:      /scratch/edk202/NLP_models/COHA/COHA/evaluation_results_test.csv
# Log directory:        /scratch/edk202/NLP_models/COHA/COHA/logs_test/evaluation
# Save mode:            overwrite
#
# Evaluation Datasets
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Similarity dataset:   ...lexichron/lib/python3.11/site-packages/gensim/test/test_data/wordsim353.tsv
# Analogy dataset:      ...hron/lib/python3.11/site-packages/gensim/test/test_data/questions-words.txt
#
# Found 198 models to evaluate
# Evaluating models: 100%|██████████| 198/198 [45:26<00:00, 13.77s/ models]
# Evaluation Complete
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Models evaluated:     198
# Results saved to:     /scratch/edk202/NLP_models/COHA/COHA/evaluation_results_test.csv
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %% [markdown]
# ### Visualize Model Performance
# The code below plots the results of the similarity and analogy tests for easy inspection.
# #### Similarity Results

# %%
plot_evaluation_results(
    corpus_path='/scratch/edk202/NLP_corpora/COHA',
    dir_suffix='test',
    genre_focus=genre_focus,
    metric='similarity_score',
    x_vars=['epochs','vector_size'],
    panel_by='year',
    plot_type='line',
    display_dpi=160
);
# Out:
# Loading evaluation results from: /scratch/edk202/NLP_models/COHA/COHA/evaluation_results_test.csv

# %% [markdown]
# #### Analogy Results

# %%
plot_evaluation_results(
    corpus_path='/scratch/edk202/NLP_corpora/COHA',
    dir_suffix='test',
    genre_focus=genre_focus,
    metric='analogy_score',
    x_vars=['epochs','vector_size'],
    panel_by='year',
    plot_type='line',
    display_dpi=160
);
# Out:
# Loading evaluation results from: /scratch/edk202/NLP_models/COHA/COHA/evaluation_results_test.csv

# %% [markdown]
# ### Regression Analysis
# The code below runs regression analyses on the similarity and analogy results.
# #### Predictors of Similarity Performance

# %%
results = run_regression_analysis(
    corpus_path='/scratch/edk202/NLP_corpora/COHA',
    dir_suffix='test',
    outcome='similarity_score',
    predictors=['year', 'vector_size', 'epochs'],
    interactions=None
)

plot_regression_results(results, display_dpi=160)
# Out:
# Loading data from: /scratch/edk202/NLP_models/COHA/COHA/evaluation_results_test.csv
# Loaded 198 observations
# Number of years: 22
#
# Model specification:
#   Formula: similarity_score ~ scale(year) + scale(vector_size) + scale(epochs)
#   Random effects: year
#
# Fitting mixed-effects model...
# Model converged successfully!
#
# ================================================================================
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:            MixedLM Dependent Variable: similarity_score
# No. Observations: 198     Method:             REML
# No. Groups:       22      Scale:              0.0001
# Min. group size:  9       Log-Likelihood:     563.0525
# Max. group size:  9       Converged:          Yes
# Mean group size:  9.0
# --------------------------------------------------------------
#                    Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           0.592    0.004 137.075 0.000  0.584  0.600
# scale(year)         0.034    0.004   7.795 0.000  0.025  0.042
# scale(vector_size) -0.002    0.001  -2.808 0.005 -0.004 -0.001
# scale(epochs)      -0.013    0.001 -17.541 0.000 -0.015 -0.012
# Group Var           0.000    0.013
# ==============================================================
#
# ================================================================================
# /scratch/edk202/.conda/envs/lexichron/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %% [markdown]
# #### Predictors of Analogy Performance

# %%
results = run_regression_analysis(
    corpus_path='/scratch/edk202/NLP_corpora/COHA',
    dir_suffix='test',
    outcome='analogy_score',
    predictors=['year', 'vector_size', 'epochs'],
    interactions=None
)

plot_regression_results(results, display_dpi=160)
# Out:
# Loading data from: /scratch/edk202/NLP_models/COHA/COHA/evaluation_results_test.csv
# Loaded 198 observations
# Number of years: 22
#
# Model specification:
#   Formula: analogy_score ~ scale(year) + scale(vector_size) + scale(epochs)
#   Random effects: year
#
# Fitting mixed-effects model...
# Model converged successfully!
#
# ================================================================================
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:             MixedLM  Dependent Variable:  analogy_score
# No. Observations:  198      Method:              REML
# No. Groups:        22       Scale:               0.0001
# Min. group size:   9        Log-Likelihood:      586.5315
# Max. group size:   9        Converged:           Yes
# Mean group size:   9.0
# --------------------------------------------------------------
#                    Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# --------------------------------------------------------------
# Intercept           0.159    0.005  34.828 0.000  0.150  0.168
# scale(year)         0.009    0.005   2.025 0.043  0.000  0.018
# scale(vector_size) -0.011    0.001 -17.752 0.000 -0.013 -0.010
# scale(epochs)       0.000    0.001   0.759 0.448 -0.001  0.002
# Group Var           0.000    0.017
# ==============================================================
#
# ================================================================================
# /scratch/edk202/.conda/envs/lexichron/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)

# %% [markdown]
# ## **Transfer or Train Final Models**
#
# We have two options now that the hyperparameter search is complete. If the desired final models are in the search set, we can simply transfer them to a new directory for analysis. Or, if the desired models aren't in the test set, we can train the final models and place them in the analysis directory.
#
# ### Transfer Final Models

# %%
from train.word2vec.config import construct_model_path
import os

model_dir = construct_model_path(db_path_stub)

# Add subdirectory for consistency (always done now)
corpus_name = os.path.basename(db_path_stub.rstrip('/'))
if genre_focus is not None:
    genre_suffix = "+".join(sorted(genre_focus))
    genre_subdir = f"{corpus_name}_{genre_suffix}"
else:
    genre_subdir = corpus_name
model_dir = os.path.join(model_dir, genre_subdir)

source_dir = Path(f'{model_dir}/models_test')
dest_dir = Path(f'{model_dir}/models_final')

if dest_dir.exists():
    shutil.rmtree(dest_dir)
dest_dir.mkdir(parents=True)

transferred = 0
for model_file in source_dir.glob('*.kv'):
    if 'vs100' in model_file.name and 'e010' in model_file.name:
        shutil.copy2(model_file, dest_dir / model_file.name)
        transferred += 1

print(f"Transferred {transferred} models from {source_dir} to {dest_dir}")
# Out:
# Transferred 22 models from /scratch/edk202/NLP_models/COHA/COHA/models_test to /scratch/edk202/NLP_models/COHA/COHA/models_final

# %% [markdown]
# ### Train Final Models

# %%
train_models(
    corpus_path=db_path_stub,
    genre_focus=genre_focus,
    years=(1900, 2000),
    year_step=1,
    dir_suffix='final',
    weight_by=('none',),
    vector_size=(100,),
    window=(10,),
    min_count=(1,),
    approach=('skip-gram',),
    epochs=(10,),
    max_parallel_models=11,
    workers_per_model=9,
    mode="restart",
    unk_mode="retain",
    use_corpus_file=True
);
# Out:
# WORD2VEC MODEL TRAINING
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2025-12-22 22:51:42
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Database:             /scratch/edk202/NLP_corpora/COHA/COHA_filtered
# Model directory:      /scratch/edk202/NLP_models/COHA/COHA/models_final
# Log directory:        /scratch/edk202/NLP_models/COHA/COHA/logs_final/training
# Parallel models:      11
#
# Training Parameters
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Years:                1900–2000 (101 years)
# Weighting:            ('none',)
# Vector size:          (100,)
# Context window:       (10,)
# Minimum word count:   (1,)
# Approach:             ('skip-gram',)
# Training epochs:      (30,)
#
# Data Options
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# UNK mode:             retain
# Corpus mode:          Shared corpus file (one per year/weight)
# Workers per model:    9
#
# Execution
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Total models in grid: 101
# Models to train:      101
# Parameter combos:     1
# Years:                101
#
# Creating corpus files in parallel...
#   Created corpus file for year 1924, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1924_wbnone_0miz7eec.txt
#   Created corpus file for year 1912, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1912_wbnone_7vkfer58.txt
#   Created corpus file for year 1936, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1936_wbnone_5v4pzek6.txt
#   Created corpus file for year 1902, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1902_wbnone_wq3wlb5s.txt
#   Created corpus file for year 1991, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1991_wbnone_vl3ct0ai.txt
#   Created corpus file for year 1940, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1940_wbnone_zzu8tbpu.txt
#   Created corpus file for year 1917, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1917_wbnone_61xyrgi4.txt
#   Created corpus file for year 1950, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1950_wbnone_0idvck82.txt
#   Created corpus file for year 1966, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1966_wbnone_kiwhcjbn.txt
#   Created corpus file for year 1908, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1908_wbnone_b3mcgtu6.txt
#   Created corpus file for year 1932, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1932_wbnone_h0ef6cm0.txt
#   Created corpus file for year 1947, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1947_wbnone_jpe9pmge.txt
#   Created corpus file for year 1975, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1975_wbnone_ykmh993q.txt
#   Created corpus file for year 1934, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1934_wbnone_y43hhl3g.txt
#   Created corpus file for year 1990, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1990_wbnone_8ye11sin.txt
#   Created corpus file for year 1973, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1973_wbnone_5jvz04rp.txt
#   Created corpus file for year 1945, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1945_wbnone_bf0m6suo.txt
#   Created corpus file for year 1958, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1958_wbnone_mrrii2by.txt
#   Created corpus file for year 2000, weight_by=none: /state/partition1/job-440869/w2v_corpus_y2000_wbnone_wcepbkku.txt
#   Created corpus file for year 1983, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1983_wbnone_810313mq.txt
#   Created corpus file for year 1937, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1937_wbnone_jtdwgdnz.txt
#   Created corpus file for year 1931, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1931_wbnone_l_0ycsn_.txt
#   Created corpus file for year 1998, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1998_wbnone_32xfw824.txt
#   Created corpus file for year 1982, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1982_wbnone_dqmii0qi.txt
#   Created corpus file for year 1976, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1976_wbnone_zx1n501s.txt
#   Created corpus file for year 1923, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1923_wbnone_0hpih0uf.txt
#   Created corpus file for year 1925, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1925_wbnone_qfpbpmkh.txt
#   Created corpus file for year 1948, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1948_wbnone_n1hwa6av.txt
#   Created corpus file for year 1916, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1916_wbnone_vw7sax17.txt
#   Created corpus file for year 1915, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1915_wbnone_5_w2vy57.txt
#   Created corpus file for year 1984, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1984_wbnone_kth2tj_a.txt
#   Created corpus file for year 1957, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1957_wbnone_qllkqd9y.txt
#   Created corpus file for year 1968, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1968_wbnone_n4407ozt.txt
#   Created corpus file for year 1967, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1967_wbnone_kgb_eqed.txt
#   Created corpus file for year 1980, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1980_wbnone_3ugslpin.txt
#   Created corpus file for year 1927, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1927_wbnone_fjvkp5mi.txt
#   Created corpus file for year 1971, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1971_wbnone_gqaf5hra.txt
#   Created corpus file for year 1962, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1962_wbnone_sztu9agg.txt
#   Created corpus file for year 1970, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1970_wbnone_i6s5eb4w.txt
#   Created corpus file for year 1993, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1993_wbnone_d70uqhvo.txt
#   Created corpus file for year 1906, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1906_wbnone_tdd3y3l3.txt
#   Created corpus file for year 1926, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1926_wbnone__ohk9fw_.txt
#   Created corpus file for year 1996, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1996_wbnone_pme6e4d7.txt
#   Created corpus file for year 1903, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1903_wbnone_qdgplatr.txt
#   Created corpus file for year 1941, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1941_wbnone_i1y67t0w.txt
#   Created corpus file for year 1939, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1939_wbnone_e8ntb_xk.txt
#   Created corpus file for year 1928, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1928_wbnone_fy69ghb7.txt
#   Created corpus file for year 1901, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1901_wbnone_awc3qa9u.txt
#   Created corpus file for year 1943, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1943_wbnone_1w9vfjkw.txt
#   Created corpus file for year 1964, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1964_wbnone_rmeubau3.txt
#   Created corpus file for year 1949, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1949_wbnone_rsf9bfr1.txt
#   Created corpus file for year 1914, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1914_wbnone_ybqn0eqs.txt
#   Created corpus file for year 1944, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1944_wbnone_ufyixo41.txt
#   Created corpus file for year 1979, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1979_wbnone_xy43hzwz.txt
#   Created corpus file for year 1961, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1961_wbnone_rcexk7dk.txt
#   Created corpus file for year 1905, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1905_wbnone_pzx1scye.txt
#   Created corpus file for year 1978, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1978_wbnone_zdw3ogtm.txt
#   Created corpus file for year 1918, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1918_wbnone_j9efhslt.txt
#   Created corpus file for year 1907, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1907_wbnone_evag5g0j.txt
#   Created corpus file for year 1963, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1963_wbnone_v9b3pspm.txt
#   Created corpus file for year 1977, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1977_wbnone_e7iphcff.txt
#   Created corpus file for year 1959, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1959_wbnone_abxt_hut.txt
#   Created corpus file for year 1956, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1956_wbnone_2_dpmkl2.txt
#   Created corpus file for year 1987, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1987_wbnone_tk9or6kd.txt
#   Created corpus file for year 1986, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1986_wbnone_7ojct8fn.txt
#   Created corpus file for year 1988, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1988_wbnone_6f82c8uy.txt
#   Created corpus file for year 1904, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1904_wbnone_pnp2ykbm.txt
#   Created corpus file for year 1929, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1929_wbnone_xmzg_tco.txt
#   Created corpus file for year 1992, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1992_wbnone_pq9hiojq.txt
#   Created corpus file for year 1913, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1913_wbnone_mxt3ofyu.txt
#   Created corpus file for year 1910, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1910_wbnone_bgmhbbiu.txt
#   Created corpus file for year 1985, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1985_wbnone_lidak894.txt
#   Created corpus file for year 1989, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1989_wbnone_lmf37ezo.txt
#   Created corpus file for year 1999, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1999_wbnone_cnd7rhez.txt
#   Created corpus file for year 1938, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1938_wbnone_1o_ob163.txt
#   Created corpus file for year 1935, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1935_wbnone_jbh1ihjy.txt
#   Created corpus file for year 1919, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1919_wbnone_licbodl_.txt
#   Created corpus file for year 1933, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1933_wbnone_sqql3c_d.txt
#   Created corpus file for year 1930, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1930_wbnone_zdoujurt.txt
#   Created corpus file for year 1994, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1994_wbnone_rg0fvuxb.txt
#   Created corpus file for year 1900, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1900_wbnone_pdk56r1m.txt
#   Created corpus file for year 1972, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1972_wbnone_mddhzh4p.txt
#   Created corpus file for year 1946, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1946_wbnone_m2vv5rhc.txt
#   Created corpus file for year 1969, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1969_wbnone_f72lncwf.txt
#   Created corpus file for year 1954, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1954_wbnone_aygm1go7.txt
#   Created corpus file for year 1953, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1953_wbnone_nz1r2mib.txt
#   Created corpus file for year 1942, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1942_wbnone_itqomrby.txt
#   Created corpus file for year 1955, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1955_wbnone_lg1vrga5.txt
#   Created corpus file for year 1952, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1952_wbnone_q1safexn.txt
#   Created corpus file for year 1981, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1981_wbnone_vxmjgc76.txt
#   Created corpus file for year 1909, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1909_wbnone_01twogkw.txt
#   Created corpus file for year 1960, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1960_wbnone_bvuepfax.txt
#   Created corpus file for year 1997, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1997_wbnone_h720hjxo.txt
#   Created corpus file for year 1921, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1921_wbnone_35mbo2tc.txt
#   Created corpus file for year 1995, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1995_wbnone_p6lfao2w.txt
#   Created corpus file for year 1920, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1920_wbnone_3apos52l.txt
#   Created corpus file for year 1974, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1974_wbnone_64c2usrr.txt
#   Created corpus file for year 1965, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1965_wbnone_8vj9iv0v.txt
#   Created corpus file for year 1951, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1951_wbnone_apjcetam.txt
#   Created corpus file for year 1911, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1911_wbnone_s8aaabm7.txt
#   Created corpus file for year 1922, weight_by=none: /state/partition1/job-440869/w2v_corpus_y1922_wbnone_st9s_flx.txt
# Training Models: 100%|██████████| 101/101 [12:00<00:00,  7.13s/ models]
# Training Complete
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Models trained:       101
# Model directory:      /scratch/edk202/NLP_models/COHA/COHA/models_final
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# %% [markdown]
# ## **Normalize and Align Models**
#
# Before we can use the models for diachronic analysis, we need to unit-normalize the vectors and align them across years using Procrustes rotation. The `normalize_and_align_vectors` function does this.

# %%
normalize_and_align_vectors(
    corpus_path=db_path_stub,
    genre_focus=genre_focus,
    weighted_alignment=True,
    stability_method='combined',
    include_frequency=True,
    frequency_weight=0.3,
    dir_suffix='final',
    anchor_year=1900,
    workers=100
)
# Out:
# WORD2VEC MODEL NORMALIZATION & ALIGNMENT
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2026-01-16 00:23:51
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Model directory:      /scratch/edk202/NLP_models/COHA/COHA/models_final
# Output directory:     /scratch/edk202/NLP_models/COHA/COHA/models_final/norm_and_align
# Anchor year:          1900
# Total models:         22
# Parallel workers:     100
#
# Alignment Method
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Type:                 Weighted Procrustes
# Stability metric:     combined
# Include frequency:    Yes
# Frequency weight:     0.30 (30% frequency, 70% stability)
#
#
# Stability Weight Computation
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Loading 22 models...
# Loading models: 100%|██████████| 22/22 [00:00<00:00, 39.45it/s]
# Computing shared vocabulary...
# Shared vocabulary size: 17630 words
# Computing stability weights using combined + frequency (weight=0.30) for 17630 words across 22 models...
# Computing combined stability metric...
# Computing mean frequency scores...
# Final weight range: 0.0446 (lowest) to 0.9897 (highest)
#
# Top 10 highest-weighted words:
#   he                   0.9897
#   one                  0.9655
#   his                  0.9566
#   make                 0.9384
#   him                  0.9361
#   way                  0.9068
#   seem                 0.9067
#   think                0.9054
#   go                   0.8976
#   may                  0.8940
#
# Processing Models
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Aligning models: 100%|██████████| 21/21 [00:21<00:00,  1.00s/ models]
# Alignment Complete
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Models processed:     22
# Output directory:     /scratch/edk202/NLP_models/COHA/COHA/models_final/norm_and_align
# Total runtime:        0:00:25.241425
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
