# %% [markdown]
# # **Davies Corpus: Acquisition Workflow**
# This workflow ingests a locally downloaded Davies corpus (e.g., COHA, COCA) into a RocksDB database. Unlike Google Books ngrams which are downloaded on-the-fly, Davies corpora must be obtained separately and stored locally before running this notebook.

# %% [markdown]
# ## **Setup**
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

from stop_words import get_stop_words
from ngramprep.ngram_filter.lemmatizer import CachedSpacyLemmatizer
from daviesprep.davies_acquire import ingest_davies_corpus
from daviesprep.davies_filter import filter_davies_corpus, write_whitelist
from ngramprep.utilities.peek import db_head, db_peek

# %% [markdown]
# ### Configure
# Here we set basic parameters: the corpus name, local path to the downloaded corpus files, and database storage paths.

# %%
corpus_name = 'COHA'
genre_focus = ['mag']
db_path_stub = f'/scratch/edk202/NLP_corpora/{corpus_name}/'

# %% [markdown]
# ## **Ingest Corpus into Database**

# %%
combined_bigrams = {
    "working class", "working classes",
    "middle class", "middle classes",
    "lower class", "lower classes",
    "upper class", "upper classes",
    "human being", "human beings"
}

ingest_davies_corpus(
    db_path_stub = db_path_stub,
    genre_focus=genre_focus,
    workers=24,
    write_batch_size=500_000,
    compact_after=True,
    combined_bigrams=combined_bigrams
)
# Out:
# COHA CORPUS ACQUISITION
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2025-12-19 19:28:02
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Corpus path:          /scratch/edk202/NLP_corpora/COHA
# Text directory:       /scratch/edk202/NLP_corpora/COHA/text
# DB path:              /scratch/edk202/NLP_corpora/COHA/COHA_mag
# Text files found:     20
# Genre focus:          mag
# Key format:           Year-only (training-ready)
# Workers:              24
# Batch size:           500,000
#
# Processing Files
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Files Processed: 100%|█████████████████████████████████████████████████████████| 20/20 [00:25<00:00]
# Post-Ingestion Compaction
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Compaction completed in 0:00:12
#
# Processing complete!
#
# Final Summary
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Files processed:          20/20
# Failed files:             0
# Total sentences written:  4,580,686
# Database path:            /scratch/edk202/NLP_corpora/COHA/COHA_mag
#
# Genre breakdown:
#   mag        4,580,686 sentences
#
# End Time: 2025-12-19 19:28:41
# Total Runtime: 0:00:38.587874

# %% [markdown]
# ## **Filter Database**

# %%
filter_options = {
    'stop_set': set(get_stop_words("english")),
    'lemma_gen': CachedSpacyLemmatizer()
}

always_include_tokens = {
    "working-class", "working-classes",
    "middle-class", "middle-classes",
    "lower-class", "lower-classes",
    "upper-class", "upper-classes",
    "human-being", "human-beings"
}

filter_davies_corpus(
    db_path_stub=db_path_stub,
    genre_focus=genre_focus,
    workers=100,
    batch_size=250_000,
    create_whitelist=True,
    apply_whitelist=True,
    whitelist_size=30_000,
    whitelist_spell_check=True,
    whitelist_year_range=(1900, 2000),
    compact_after=True,
    always_include=always_include_tokens,
    **filter_options
)
# Out:
# COHA CORPUS FILTERING
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Start Time: 2025-12-19 19:28:53
#
# Configuration
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Source DB:            /scratch/edk202/NLP_corpora/COHA/COHA_mag
# Destination DB:       /scratch/edk202/NLP_corpora/COHA/COHA_mag_filtered
# Lowercase:            True
# Alpha only:           True
# Filter short:         True (min_len=3)
# Filter stops:         True
# Apply lemmas:         True
# Workers:              100
# Batch size:           250,000
#
# Processing Sentences
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Batches Processed: 100%|███████████████████████████████████████████████████████| 19/19 [00:15<00:00]
# Building Whitelist
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Whitelist path:          /scratch/edk202/NLP_corpora/COHA/COHA_mag_whitelist.txt
# Top N tokens:            30,000
# Year range:              1900-2000
# Spell check:             True
#
# Scanning database...
# Found 4,312,837 sentences in 87 batches
# Detecting years present in corpus...
# Building token frequencies: 100%|██████████████████████████████████████████████| 87/87 [00:44<00:00]
# Years present in corpus within range: 11 years
#   Range: 1900 to 2000
#   Years: [1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000]
#
# Filtering tokens by year coverage (must appear in all 11 years)...
# Tokens before year filter: 54,263
# Tokens after year filter:  16,330
# Tokens removed:            37,933
#
# Ranking 16,330 unique tokens...
# Added 1 always_include tokens that were not found in corpus
# Selected top 30,000 tokens (+ 0 always_include)
# Writing whitelist to /scratch/edk202/NLP_corpora/COHA/COHA_mag_whitelist.txt...
# Whitelist written successfully: /scratch/edk202/NLP_corpora/COHA/COHA_mag_whitelist.txt
#
# Applying Whitelist
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Loading whitelist into memory...
# Loaded 16,330 tokens from whitelist
#
# Replacing non-whitelist tokens with <UNK>...
# Batches Processed: 100%|███████████████████████████████████████████████████████| 18/18 [00:13<00:00]
# Whitelist application complete!
# Sentences processed:      4,312,837
# Sentences modified:       17,589
#
# Post-Filter Compaction
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Initial DB size:         624.40 MB
# Compaction completed in 0:00:07
# Size before:             624.40 MB
# Size after:              624.40 MB
# Space saved:             1.35 KB (0.0%)
#
#
# Processing complete!
#
# Final Summary
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Sentences read:           4,510,852
# Writes accumulated:       4,319,570
# Sentences rejected:       191,282
# Retention rate:           95.8%
# Destination DB:           /scratch/edk202/NLP_corpora/COHA/COHA_mag_filtered
#
# End Time: 2025-12-19 19:30:42
# Total Runtime: 0:01:49.645953

# %% [markdown]
# ## **Optional: Inspect Database**

# %% [markdown]
# ### `db_head`: Show first N records

# %%
db_path = f'/scratch/edk202/NLP_corpora/{corpus_name}/{corpus_name}'

db_head(str(db_path), n=150)
# Out:
# First 150 key-value pairs:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# [ 1] Key:   [1810] &; Leon
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 2] Key:   [1810] &; Mad
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 3] Key:   [1810] &; Moth
#      Value: Total: 2 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 4] Key:   [1810] &; Stur
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 5] Key:   [1810] &; urg 'd him to the grave where sleeps His greatness Borodino 's field
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 6] Key:   [1810] 'm thine
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 7] Key:   [1810] 's defeated The whole rank 's slaughter 'd scarce a man escap 'd To tell their fate
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 8] Key:   [1810] 's my mother
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [ 9] Key:   [1810] 's royal spirit Would treat of peace
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [10] Key:   [1810] 've seen enough order the servants to shut all the doors and windows Oh
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [11] Key:   [1810] 've told you all my master 's names except two and one of them is Jake Flutercase
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [12] Key:   [1810] ( 1st Broker writes and Shaver advances on the stage
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [13] Key:   [1810] ( 2 ) and juries are to be the arbiters of justice
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [14] Key:   [1810] ( A boy at the door
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [15] Key:   [1810] ( A distant bugle
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [16] Key:   [1810] ( A distant flourish of kettle-drums
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [17] Key:   [1810] ( A general fire
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [18] Key:   [1810] ( A gun is fired at a distance
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [19] Key:   [1810] ( A knock at the door
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [20] Key:   [1810] ( A knocking at the door
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [21] Key:   [1810] ( A letter appears suspended from an upper grated window by strips of silk and strings and ribbons tied together it comes down almost within Zeikel 's reach
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [22] Key:   [1810] ( A loud noise of arms without
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [23] Key:   [1810] ( A noise is heard at the latch of the door leading to Lena 's apartment
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [24] Key:   [1810] ( A noise without
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [25] Key:   [1810] ( A pause
#      Value: Total: 2 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [26] Key:   [1810] ( A race in sacks
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [27] Key:   [1810] ( A rapping without
#      Value: Total: 2 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [28] Key:   [1810] ( A saul is imperfectly seen in the distance
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [29] Key:   [1810] ( A violent crash of thunder and the statue of Tarquin struck by a flash is shatter 'd to pieces
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [30] Key:   [1810] ( A violent rapping as from an outer gate
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [31] Key:   [1810] ( A waggoner
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [32] Key:   [1810] ( Abdel wrests the dagger from her without receiving injury ) Abdel
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [33] Key:   [1810] ( Achmet converses with the company
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [34] Key:   [1810] ( Achmet examines the bills
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [35] Key:   [1810] ( Achmet speaks apart to the Lisbero
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [36] Key:   [1810] ( Achmet turns and looks at Ellinor
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [37] Key:   [1810] ( Achmet turns away
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [38] Key:   [1810] ( Addressing the Admiral ) You a Russian Admiral with a new name
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [39] Key:   [1810] ( Addressing the skin )
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [40] Key:   [1810] ( Ade
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [41] Key:   [1810] ( Advancing towards Maria ) How does Miss Devalmore
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [42] Key:   [1810] ( Advancing towards him
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [43] Key:   [1810] ( Affected
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [44] Key:   [1810] ( Affecting an air of mystery and sorrow
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [45] Key:   [1810] ( After a desperate contest Conrad is at length made prisoner with most of his band who Turks
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [46] Key:   [1810] ( Alarm Drum ) Jack
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [47] Key:   [1810] ( Alarm drums beat along the lines
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [48] Key:   [1810] ( All anxiously press around the General
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [49] Key:   [1810] ( All enter the house
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [50] Key:   [1810] ( All except the elder chief Gonsalvo exclaim
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [51] Key:   [1810] ( All start
#      Value: Total: 2 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [52] Key:   [1810] ( All the Servants collect around Woodville
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [53] Key:   [1810] ( All the time the lawyer is speaking the old man mutters and steps about at the same time the lawyer speaks louder and louder
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [54] Key:   [1810] ( All utter ejaculations of surprise
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [55] Key:   [1810] ( Almeyda and Arandez exeunt across the bridge
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [56] Key:   [1810] ( Almeyda and Arandez remain stupified Carlos stands forward ) Eug
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [57] Key:   [1810] ( Almeyda turns to go ) Stay my lord and forgive my petulance
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [58] Key:   [1810] ( Aloud
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [59] Key:   [1810] ( Altorf turns also on the soldiers who are driven off
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [60] Key:   [1810] ( Amelia courtesys ) Baron
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [61] Key:   [1810] ( Amelia goes out Arnaud opens the door introduces FREDERICK and retires ) Baron
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [62] Key:   [1810] ( Amelia sits down at tea table ) What sort of weather have we
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [63] Key:   [1810] ( And soon Bertocci to his cost shall learn How mad he was to cross me in my love To slay my nephew and my much lov 'd brother What though in rebel arms
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [64] Key:   [1810] ( And sweet I must confess would be the draught
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [65] Key:   [1810] ( Anna and Sophia exeunt with the flag
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
#
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [108] Key:   [1810] ( Cam
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [109] Key:   [1810] ( Capt
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [110] Key:   [1810] ( Carlo goes out ) Now hath arrived the most blissful moment that the heart of man can know the moment when hatred and prejudice are driven from their hold and love and nature take their place
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [111] Key:   [1810] ( Carlos affects surprise at being known ) Bea
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [112] Key:   [1810] ( Carlos again affects astonishment ) Bea
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [113] Key:   [1810] ( Carlos does not reply
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [114] Key:   [1810] ( Carlos forces Gusman off ) Pac
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [115] Key:   [1810] ( Carlos is indignant ) What is your rank
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [116] Key:   [1810] ( Carlos replies with a profound reverence ) Alm
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [117] Key:   [1810] ( Carlos smiles ) Pac
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [118] Key:   [1810] ( Carolina discovered reclining on a rock
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [119] Key:   [1810] ( Carolina flies into his arms
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [120] Key:   [1810] ( Carolina shrieks
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [121] Key:   [1810] ( Carolina starts and falls senseless at the foot of the altar
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [122] Key:   [1810] ( Caroline
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [123] Key:   [1810] ( Caroline attempting to leave the room James detains her
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [124] Key:   [1810] ( Casting him off
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [125] Key:   [1810] ( Catching Charles in her arms she throws herself upon the corpse while Maria leans over them in mingled horror and despair
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [126] Key:   [1810] ( Caution places himself between them takes out his paper and examines them minutely
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [127] Key:   [1810] ( Charge sounded
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [128] Key:   [1810] ( Charles is heard to cry from the floor above as if frightened
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [129] Key:   [1810] ( Charles runs into his mother 's arms
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [130] Key:   [1810] ( Chatahoochie and Tookaubatcha steal into the house Sneakwell steps aside
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [131] Key:   [1810] ( Checking himself
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [132] Key:   [1810] ( Clara who supported Constance during the first part of the speech at the last words lets her go and she sinks on her knees ) Clara
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [133] Key:   [1810] ( Clerk opens the door
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [134] Key:   [1810] ( Clerks laugh
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [135] Key:   [1810] ( Cloddy runs off
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [136] Key:   [1810] ( Collecting his courage and looking towards the audience ) Well
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [137] Key:   [1810] ( Collecting his fortitude then addressing Harriet
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [138] Key:   [1810] ( Coming forward
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [139] Key:   [1810] ( Conrad 's vessel is seen passing the Turkish galleys unperceived by them and anchors behind a cape in the direction of the city Chorus continues.
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [140] Key:   [1810] ( Conrad appears agitated for a moment but instantly recovers from his embarrassment and sits down in silence the slaves in the mean time have placed food before him he abstains from touching it the Pacha eyes him attentively
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [141] Key:   [1810] ( Conrad bursts the door of the Haram and enters it with all his band Music alarm drums after a short pause he returns with but one of his followers in a swoon she slowly revives
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [142] Key:   [1810] ( Conrad enters the apartment
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [143] Key:   [1810] ( Conrad grasps the hand of Pedro with expressions of affection and leaps into the boat Music the boat pushes off to the bark at anchor
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [144] Key:   [1810] ( Conrad veils his face and appears agitated with the deepest emotions
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [145] Key:   [1810] ( Constance Constance seats herself at the harp and she and the other minstrels perform the songs in the third canto of Marmion ) Where shall the lover rest Whom the fates sever From his true maiden 's breast Parted for ever
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [146] Key:   [1810] ( Constance casts a reproachful look at Marmion and goes out ) Tun
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [147] Key:   [1810] ( Constance recovering looks round on the assembly with indignation goes into the dungeon and the stone is closed upon her ) Ran
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [148] Key:   [1810] ( Courtesying distantly
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins)
#
# [149] Key:   [1810] ( Courtsies to Sir Harry
#      Value: Total: 1 occurrences in 1 volumes (1810-1810, 1 bins